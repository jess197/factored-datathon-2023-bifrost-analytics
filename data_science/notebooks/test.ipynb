# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/jessica/Library/Python/3.9/lib/python/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jessica/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jessica/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jessica/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/jessica/Library/Python/3.9/lib/python/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
conns = {'SnowflakeDB':{ 'UserName': '','Password':'', 'Host':''}}

# %%
#import the module
import snowflake.connector 

#create the connection 
connection = snowflake.connector.connect( 
    user=conns['SnowflakeDB']['UserName']
    , password=conns['SnowflakeDB']['Password']
    , account=conns['SnowflakeDB']['Host'])

# %%
import pandas as pd

# %%
query = "SELECT * FROM AMAZON.AMZ_DATA_SILVER.METADATA LIMIT 10"
df = pd.read_sql_query(query, connection)

display(df)
# Out:
# /var/folders/__/yd2xb0114nl_x78dddwtn9k00000gn/T/ipykernel_34372/946907670.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#                        METADATA_KEY  \
# 0  e659d169025ef964680aa3f9f429123a
# 1  8292381376d23882d5c0857e2181b328
# 2  cbe742da15d262f6dc09fff9a35e6283
# 3  6626f6cec5cb044bf7ecbc72aa5090bc
# 4  09debb283d7f2f2e0a80de0010a859fb
# 5  68560a99c8325ce360ca8903d7183ce7
# 6  0ffe89a4beaca6cfbcc2a3df515bbe7e
# 7  1df31b547aeb71a944b5154bdc04309e
# 8  2225ab4ee799a87b8f740b63bf4e2a9f
# 9  234ab6251d45bcbf6af91d9d3f860bbc
#
#                                                TITLE        ASIN  \
# 0          Organ and Piano Duets for the Church Year  0893282502
# 1      Robert Adams: Summer Nights (New Images Book)  0893811416
# 2  The Plus 10 Percent Principle: How to Get Extr...  0893842214
# 3  Nurse Staffing and Patient Classification: Str...  089443943X
# 4                                     Rocket Phonics  0894558714
# 5                            The Circuit Party Vol 8  B00008CQNV
# 6                    Live: Ballad Of An Outlaw Woman  B00008DGRJ
# 7   Integrity Music's Scripture Memory Songs: Praise  B00008F8C9
# 8                                        Celebration  B00008FTXK
# 9               Top Hits Of The Sixties: Groovy Hits  B00008IALJ
#
#                                     BRAND  \
# 0                              Lani Smith
# 1        Visit Amazon's Robert Adams Page
# 2   Visit Amazon's Barrie Richardson Page
# 3                   Elizabeth Nance Lewis
# 4  Maureen Guffanti Stephen Guffanti M.D.
# 5                       CIRCUIT PARTY -8-
# 6                                Fenix*Tx
# 7                           Mark Gasbarro
# 8                         Kool & The Gang
# 9                         VARIOUS ARTISTS
#
#                                             CATEGORY DATE   PRICE  \
# 0                   Books, Arts & Photography, Music       127.28
# 1  Books, Arts and Photography, Photography and V...          NaN
# 2  Books, Business and Money, Management and Lead...          NaN
# 3  Books, New, Used and Rental Textbooks, Social ...          NaN
# 4                                                           14.48
# 5             CDs & Vinyl, Dance & Electronic, House        12.99
# 6                                   CDs & Vinyl, Pop        10.98
# 7         CDs & Vinyl, Christian, Pop & Contemporary         2.99
# 8                             CDs & Vinyl, R&B, Funk        19.99
# 9              CDs & Vinyl, Pop, Oldies, Girl Groups        15.98
#
#                                              DETAILS FEATURE  MAIN_CATEGORY  \
# 0                                               None      []          Books
# 1                                               None      []          Books
# 2                                               None      []          Books
# 3                                               None      []          Books
# 4                                               None      []          Books
# 5  {\n  "ASIN:": "B00008CQNV",\n  "Audio CD": "(N...      []  Digital Music
# 6  {\n  "ASIN:": "B00008DGRJ",\n  "Audio CD": "(J...      []  Digital Music
# 7  {\n  "ASIN:": "B00008F8C9",\n  "Audio Cassette...      []  Digital Music
# 8  {\n  "ASIN:": "B00008FTXK",\n  "Audio Cassette...      []  Digital Music
# 9  {\n  "ASIN:": "B00008IALJ",\n  "Audio CD": "(A...      []  Digital Music
#
#                                             ALSO_BUY  \
# 0
# 1  3869309008, 0989785998, 0385266510, 386521956X...
# 2
# 3
# 4
# 5  B000065QJK, B00004SYT3, B00005089J, B00005JG8M...
# 6  B00005LB9E, B001EAWRHY, B000GTJUQK, B003O9I0L0...
# 7                 B00008F8C6, B00008F8C7, B00008F8CI
# 8
# 9
#
#                                            ALSO_VIEW  \
# 0                             0834172720, 0793529689
# 1  1597111171, B000I0RSYI, 3958291694, 0935640967...
# 2
# 3
# 4
# 5
# 6
# 7  B00008F8D6, B00008F8D7, B00008F8D8, B00008F8DB...
# 8
# 9  B00008IALL, B00020W056, B00005QDTF, B00006LSNA...
#
#                          RANK      INGESTION_DATE
# 0        5,362,697 in Books ( 2023-07-29 00:52:15
# 1        1,246,046 in Books ( 2023-07-29 00:52:15
# 2        1,398,106 in Books ( 2023-07-29 00:52:15
# 3       17,875,279 in Books ( 2023-07-29 00:52:15
# 4        3,862,735 in Books ( 2023-07-29 00:52:15
# 5    475,334 in CDs & Vinyl ( 2023-07-29 00:58:53
# 6    326,300 in CDs & Vinyl ( 2023-07-29 00:58:53
# 7    872,901 in CDs & Vinyl ( 2023-07-29 00:58:53
# 8  3,198,488 in CDs & Vinyl ( 2023-07-29 00:58:53
# 9    306,039 in CDs & Vinyl ( 2023-07-29 00:58:53
